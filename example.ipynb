# %%
from exp_lums import lum_abu as ela
ela1 = ela(dt = 3e6, dm = 0.01, tend = 1e9, sfh = [[0,1],[13e9,1]], imf_type = 'kroupa', alpha = [-0.3, -1.3, -2.3], imf_bdys = [0.01, 100], mass_lim = [0.08, 0.5], lum_func = 'duric_slaris', lifetime_file = '/lifes/life_schaller_92.txt', z_evol = [[0,0.01], [13e9, 0.01]])
# Out:
# Stars start to shinning
#    Shinning end. Using 5.27 s.
